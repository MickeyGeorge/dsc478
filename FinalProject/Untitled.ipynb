# %%
## Janke Final

# %%
## Load Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
## Read in file
## Set low_memory=False to deal with mix datatype errors
crashtable = pd.read_csv("2c13021f-74a9-4289-a1e5-fe0472c89881.csv", index_col=0, low_memory=False)

crashtable.shape
# Out:
# (170365, 189)

# %%
crashtable.head()
# Out:
#             DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  CRASH_YEAR  \
# CRASH_CRN
# 2004000001        11             2          2454       02454        2004
# 2004000010        11             2          2440       02440        2004
# 2004000016        11             2          2203       02203        2004
# 2004000022        11             2          2404       02404        2004
# 2004000030        11             2          2419       02419        2004
#
#             CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  HOUR_OF_DAY  ILLUMINATION  \
# CRASH_CRN
# 2004000001            1            5        257.0          2.0             2
# 2004000010            1            5       1027.0         10.0             1
# 2004000016            1            5       1839.0         18.0             2
# 2004000022            1            6        914.0          9.0             1
# 2004000030            1            5       2230.0         22.0             3
#
# ...
